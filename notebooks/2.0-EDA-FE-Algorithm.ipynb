# %% [markdown]
# # Exploratory Data Analysis and Feature Engineering
#
# Use this notebook to inspect the dataset, prepare features, and compare algorithms.

# %%
import pandas as pd

# Load your dataset here.
# data = pd.read_csv("../data/dataset.csv")
# data.head()
