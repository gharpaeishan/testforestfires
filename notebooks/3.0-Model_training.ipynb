# %% [markdown]
# # Model Training
#
# Train, evaluate, and export the selected machine-learning model.

# %%
from pathlib import Path

MODEL_DIR = Path("../models")
MODEL_DIR.mkdir(exist_ok=True)

# Add preprocessing, training, evaluation, and model export steps here.
